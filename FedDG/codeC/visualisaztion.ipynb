# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
data = pd.read_csv('output_unetpp.csv')
print(data.head())
# Out:
#    epoch    lossArr  dicelist    jclist    hd95list   assdlist    splist  \
# 0      0  10.184246  0.047915  0.023255  127.306790  36.033636  0.081227
# 1      1   6.554072  0.016559  0.008457  123.240977  36.351629  0.362278
# 2      2   3.110408  0.068346  0.040869  109.402639  31.629079  0.651305
# 3      3   1.437583  0.437383  0.385717   61.769368  13.087622  0.949422
# 4      4   1.281408  0.723935  0.610860   19.424450   2.938668  0.980258
#
#    recalllist   prelist
# 0    0.702582  0.023358
# 1    0.152139  0.008600
# 2    0.410418  0.042963
# 3    0.735888  0.478617
# 4    0.913233  0.657942

# %%
plt.plot(data['epoch'], data['lossArr'])  # 替换 'Column1' 和 'Column2' 为你想要绘制的列名
# plt.plot(data['epoch'], data['dicelist']) 
# plt.plot(data['epoch'], data['jclist']) 
# plt.plot(data['epoch'], data['hd95list']) 
# plt.plot(data['epoch'], data['assdlist']) 
# plt.plot(data['epoch'], data['splist']) 
# plt.plot(data['epoch'], data['recalllist']) 
# plt.plot(data['epoch'], data['prelist']) 
plt.xlabel('X')
plt.ylabel('Y')
plt.legend([ 
    'lossArr',
            # 'dicelist',
            # 'jclist',
            # 'hd95list',
            # 'assdlist',
            # 'splist',
            # 'recalllist',
            # 'prelist'
])
plt.show()
plt.save("hello.png")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 22
#      11 plt.legend([
#      12     'lossArr',
#      13             # 'dicelist',
#    (...)
#      19             # 'prelist'
#      20 ])
#      21 plt.show()
# ---> 22 plt.save("hello.png")
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'save'
